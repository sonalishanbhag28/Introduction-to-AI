# %% [markdown]
# # Pandas Library Assignment II
#
# Sonali Shripad Shanbhag
# 19BDS0114
#
# Questions:
# 1. Perform some operations like Slicing, Merging, Concatenation and Joining.
# 2. Read a dataset and find out null values
# 3. Find unique values, change the column and index names
# 4. Calculate mean, median and mode for continuous data.

# %%
import pandas as pd

# %% [markdown]
# Creating Data Frames

# %%
df1=pd.DataFrame({'Name' : ['Sonali', 'Riya', 'Riddhi', 'Sona', 'Shakti'], 'Age': [20,19,19,20,20], 'Marks': [100, 95, 90, 85, 80]})
df1
# Out:
#      Name  Age  Marks
# 0  Sonali   20    100
# 1    Riya   19     95
# 2  Riddhi   19     90
# 3    Sona   20     85
# 4  Shakti   20     80

# %%
df2=pd.DataFrame({'Name' : ['Sonali', 'Riya', 'Riddhi', 'Sona', 'Shakti'],'RollNo' : [114, 115, 116, 117, 118], 'Course': ['DS','CSE', 'CSE', 'CSE','DS']})
df2
# Out:
#      Name  RollNo Course
# 0  Sonali     114     DS
# 1    Riya     115    CSE
# 2  Riddhi     116    CSE
# 3    Sona     117    CSE
# 4  Shakti     118     DS

# %% [markdown]
# Slicing Operation

# %%
df1.head()
# Out:
#      Name  Age  Marks
# 0  Sonali   20    100
# 1    Riya   19     95
# 2  Riddhi   19     90
# 3    Sona   20     85
# 4  Shakti   20     80

# %%
df2.tail()
# Out:
#      Name  RollNo Course
# 0  Sonali     114     DS
# 1    Riya     115    CSE
# 2  Riddhi     116    CSE
# 3    Sona     117    CSE
# 4  Shakti     118     DS

# %%
df1.head(3)
# Out:
#      Name  Age  Marks
# 0  Sonali   20    100
# 1    Riya   19     95
# 2  Riddhi   19     90

# %%
df2.tail(2)
# Out:
#      Name  RollNo Course
# 3    Sona     117    CSE
# 4  Shakti     118     DS

# %% [markdown]
# Merging

# %%
mer=pd.merge(df1,df2,on='Name')

# %%
mer
# Out:
#      Name  Age  Marks  RollNo Course
# 0  Sonali   20    100     114     DS
# 1    Riya   19     95     115    CSE
# 2  Riddhi   19     90     116    CSE
# 3    Sona   20     85     117    CSE
# 4  Shakti   20     80     118     DS

# %% [markdown]
# Concatenation

# %%
cat=pd.concat([df1,df2],axis=1)
cat
# Out:
#      Name  Age  Marks    Name  RollNo Course
# 0  Sonali   20    100  Sonali     114     DS
# 1    Riya   19     95    Riya     115    CSE
# 2  Riddhi   19     90  Riddhi     116    CSE
# 3    Sona   20     85    Sona     117    CSE
# 4  Shakti   20     80  Shakti     118     DS

# %%
df3=pd.DataFrame({'Name' : ['Sohan','Sonam'], 'Age': [20,19], 'Marks': [88, 75]})
df3
# Out:
#     Name  Age  Marks
# 0  Sohan   20     88
# 1  Sonam   19     75

# %%
cat=pd.concat([df1,df3],axis=0)
cat
# Out:
#      Name  Age  Marks
# 0  Sonali   20    100
# 1    Riya   19     95
# 2  Riddhi   19     90
# 3    Sona   20     85
# 4  Shakti   20     80
# 0   Sohan   20     88
# 1   Sonam   19     75

# %% [markdown]
# Joining

# %%
df3=pd.DataFrame({'Name' : ['Sonali', 'Riya', 'Riddhi', 'Sona', 'Shakti'], 'Age': [20,19,19,20,20], 'Marks': [100, 95, 90, 85, 80]})
df3
# Out:
#      Name  Age  Marks
# 0  Sonali   20    100
# 1    Riya   19     95
# 2  Riddhi   19     90
# 3    Sona   20     85
# 4  Shakti   20     80

# %%
df4=pd.DataFrame({'RollNo' : [114, 115, 116, 117, 118], 'Course': ['DS','CSE', 'CSE', 'CSE','DS']})
df4
# Out:
#    RollNo Course
# 0     114     DS
# 1     115    CSE
# 2     116    CSE
# 3     117    CSE
# 4     118     DS

# %%
jn=df3.join(df4)

# %%
jn
# Out:
#      Name  Age  Marks  RollNo Course
# 0  Sonali   20    100     114     DS
# 1    Riya   19     95     115    CSE
# 2  Riddhi   19     90     116    CSE
# 3    Sona   20     85     117    CSE
# 4  Shakti   20     80     118     DS

# %%
jn=df4.join(df3)
jn
# Out:
#    RollNo Course    Name  Age  Marks
# 0     114     DS  Sonali   20    100
# 1     115    CSE    Riya   19     95
# 2     116    CSE  Riddhi   19     90
# 3     117    CSE    Sona   20     85
# 4     118     DS  Shakti   20     80

# %% [markdown]
# # Read a csv Dataset

# %%
data=pd.read_csv('Dataset.csv')
data
# Out:
#    First Name Last Name Gender  Age  Stream  Roll No      Hobby Nationality  \
# 0      Sonali  Shanbhag      F    21    CSE    114.0     Sports      Indian
# 1       Sohan       NaN      M    21    NaN    115.0    Pottery    American
# 2     Nandini     Nayak      F    20    EEE    116.0  Gardening      Indian
# 3     Shripad    Nagesh    NaN    19    ECE    117.0        NaN      Indian
# 4      Raghav     Reddy      M    18  CIVIL      NaN    Cooking    American
# 5        Riya       NaN      F    21    CSE    119.0    Singing         NaN
# 6      Riddhi    Rajesh      F    22  CIVIL    120.0    Dancing      Indian
# 7      Shakti    Balaji    NaN    17   MECH    121.0        NaN      Indian
# 8        Sona       Ann      F    18    ECE    122.0  Gardening      Indian
# 9       Rishi    Joseph      M    19    ECE      NaN    Knittng      Indian
# 10       Abhi      John      M    20    NaN    124.0    Cooking    American
# ...

# %% [markdown]
# Find null values

# %%
data.isnull().sum()
# Out:
# First Name          0
# Last Name           3
# Gender              4
# Age                 0
# Stream              3
# Roll No             2
# Hobby               4
# Nationality         2
# Year of Passing     2
# dtype: int64

# %%
data.isnull()
# Out:
#     First Name  Last Name  Gender   Age   Stream  Roll No  Hobby  Nationality  \
# 0        False      False   False  False   False    False  False        False
# 1        False       True   False  False    True    False  False        False
# 2        False      False   False  False   False    False  False        False
# 3        False      False    True  False   False    False   True        False
# 4        False      False   False  False   False     True  False        False
# 5        False       True   False  False   False    False  False         True
# 6        False      False   False  False   False    False  False        False
# 7        False      False    True  False   False    False   True        False
# 8        False      False   False  False   False    False  False        False
# 9        False      False   False  False   False     True  False        False
# 10       False      False   False  False    True    False  False        False
# ...

# %% [markdown]
# Change the index

# %%
data.set_index('Roll No', inplace=True) #set index as RollNo

# %%
data
# Out:
#         First Name Last Name Gender  Age  Stream      Hobby Nationality  \
# Roll No
# 114.0       Sonali  Shanbhag      F    21    CSE     Sports      Indian
# 115.0        Sohan       NaN      M    21    NaN    Pottery    American
# 116.0      Nandini     Nayak      F    20    EEE  Gardening      Indian
# 117.0      Shripad    Nagesh    NaN    19    ECE        NaN      Indian
# NaN         Raghav     Reddy      M    18  CIVIL    Cooking    American
# 119.0         Riya       NaN      F    21    CSE    Singing         NaN
# 120.0       Riddhi    Rajesh      F    22  CIVIL    Dancing      Indian
# 121.0       Shakti    Balaji    NaN    17   MECH        NaN      Indian
# 122.0         Sona       Ann      F    18    ECE  Gardening      Indian
# NaN          Rishi    Joseph      M    19    ECE    Knittng      Indian
# 124.0         Abhi      John      M    20    NaN    Cooking    American
# 125.0         Tara    Ratnam      F    21   MECH    Knittng         NaN
# ...

# %% [markdown]
# Change the column names

# %%
data=data.rename(columns={'Gender':'Sex'})
data
# Out:
#         First Name Last Name  Sex  Age  Stream      Hobby Nationality  \
# Roll No
# 114.0       Sonali  Shanbhag    F    21    CSE     Sports      Indian
# 115.0        Sohan       NaN    M    21    NaN    Pottery    American
# 116.0      Nandini     Nayak    F    20    EEE  Gardening      Indian
# 117.0      Shripad    Nagesh  NaN    19    ECE        NaN      Indian
# NaN         Raghav     Reddy    M    18  CIVIL    Cooking    American
# 119.0         Riya       NaN    F    21    CSE    Singing         NaN
# 120.0       Riddhi    Rajesh    F    22  CIVIL    Dancing      Indian
# 121.0       Shakti    Balaji  NaN    17   MECH        NaN      Indian
# 122.0         Sona       Ann    F    18    ECE  Gardening      Indian
# NaN          Rishi    Joseph    M    19    ECE    Knittng      Indian
# 124.0         Abhi      John    M    20    NaN    Cooking    American
# 125.0         Tara    Ratnam    F    21   MECH    Knittng         NaN
# ...

# %% [markdown]
# Calculate the mean, median and mode for continuous data

# %%
data.columns
# Out:
# Index(['First Name', 'Last Name', 'Sex', 'Age ', 'Stream', 'Hobby',
#        'Nationality', 'Year of Passing '],
#       dtype='object')

# %%
mean1=data['Age '].mean()
mean1
# Out:
# 20.470588235294116

# %%
median1=data['Age '].median()
median1
# Out:
# 21.0

# %%
mode2=data['Year of Passing '].mode()
mode2
# Out:
# 0    2022.0
# 1    2023.0
# dtype: float64
